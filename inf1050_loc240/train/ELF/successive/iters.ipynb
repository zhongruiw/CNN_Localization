# %%
# %matplotlib notebook
import sys
sys.path.append('/Users/ree/Documents/DataAssimilization/AI_localization/L05/git_repo/general')
from construct_GC_2d import construct_GC_2d
import numpy as np
import matplotlib.pyplot as plt

model_size = 960
obs_density = 4
model_grids = np.arange(1, model_size + 1)
obs_grids = model_grids[model_grids % obs_density == 0]
loc_size = int(model_size/2)+1
CMat = construct_GC_2d(240, model_size, obs_grids)


elf0 = np.load('./iter0_gc/iter0/elf_smsp.npy')
elf1 = np.load('./iter0_gc/iter1/elf_smsp.npy')
elf2 = np.load('./iter0_gc/iter2/elf_smsp.npy')
# elf3 = np.load('./iter3/elf_mva.npy')
# elf4 = np.load('./iter4/elf_mva.npy')
# elf5 = np.load('./iter5/elf_mva.npy')
# elf6 = np.load('./iter6/elf_mva.npy')

plt.plot(range(loc_size), CMat[0, 3:loc_size+3], color='g',label='GC240')
plt.plot(range(loc_size), elf0, color='yellow',label='ELF0')
plt.plot(range(loc_size), elf1, color='gold',label='ELF1')
plt.plot(range(loc_size), elf2, color='sandybrown',label='ELF2')
# plt.plot(range(loc_size), elf3, color='tomato',label='ELF3')
# plt.plot(range(loc_size), elf4, color='red',label='ELF4')
# plt.plot(range(loc_size), elf5, color='brown',label='ELF5')
# plt.plot(range(loc_size), elf6, color='black',label='ELF6')
plt.xlabel('distance')
plt.xlim(0,481)
plt.title('ELF iterated from gc240')
plt.legend()
plt.grid(True)
plt.show()
plt.savefig('elf0_gc240.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import sys
sys.path.append('/Users/ree/Documents/DataAssimilization/AI_localization/L05/git_repo/general')
from construct_GC_2d import construct_GC_2d
import numpy as np
import matplotlib.pyplot as plt

model_size = 960
obs_density = 4
model_grids = np.arange(1, model_size + 1)
obs_grids = model_grids[model_grids % obs_density == 0]
loc_size = int(model_size/2)+1
CMat = construct_GC_2d(240, model_size, obs_grids)


elf0 = np.load('./iter0_noloc/iter0/elf_smsp.npy')
elf1 = np.load('./iter0_noloc/iter1/elf_smsp.npy')
elf2 = np.load('./iter0_noloc/iter2/elf_smsp.npy')
# elf3 = np.load('./iter3/elf_mva.npy')
# elf4 = np.load('./iter4/elf_mva.npy')
# elf5 = np.load('./iter5/elf_mva.npy')
# elf6 = np.load('./iter6/elf_mva.npy')

plt.plot(range(loc_size), CMat[0, 3:loc_size+3], color='g',label='GC240')
plt.plot(range(loc_size), elf0, color='yellow',label='ELF0')
plt.plot(range(loc_size), elf1, color='gold',label='ELF1')
plt.plot(range(loc_size), elf2, color='sandybrown',label='ELF2')
# plt.plot(range(loc_size), elf3, color='tomato',label='ELF3')
# plt.plot(range(loc_size), elf4, color='red',label='ELF4')
# plt.plot(range(loc_size), elf5, color='brown',label='ELF5')
# plt.plot(range(loc_size), elf6, color='black',label='ELF6')
plt.xlabel('distance')
plt.xlim(0,481)
plt.title('ELF iterated from noloc')
plt.legend()
plt.grid(True)
plt.show()
plt.savefig('elf0_noloc.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
