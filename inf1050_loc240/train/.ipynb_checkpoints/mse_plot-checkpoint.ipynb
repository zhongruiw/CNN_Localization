# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt


MSE_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/reg/mse_gc_240.npy')
MSE_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/reg/mse_reg_1.npy')
MSE_ai = np.load('mse_ai.npy')
MSE_ai_1layer = np.load('mse_ai_1layer.npy')


model_size = 960
xx = range(model_size)
plt.plot(xx, MSE_gc, label='mse_gc')
plt.plot(xx, MSE_reg, label='mse_reg')
# plt.plot(xx, MSE_ai, label='mse_ai')
plt.plot(xx, MSE_ai_1layer, label='mse_ai')
plt.legend()
plt.show()

print('mean_mse_gc:',np.mean(MSE_gc))
print('mean_mse_reg:',np.mean(MSE_reg))
print('mean_mse_ai:',np.mean(MSE_ai))
print('mean_mse_ai:',np.mean(MSE_ai_1layer))
# Out:
# <img src="data:image/png;base64,..." width="640">
# mean_mse_gc: 1.0904496622551592e-05
# mean_mse_reg: 8.991434905914852e-06
# mean_mse_ai: 1.5237476313542324e-05
# mean_mse_ai: 1.5192979022575926e-05

# %%
a = np.arange(960)
a[958:966]
# Out:
# array([958, 959])

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from construct_GC_2d import construct_GC_2d

# -------------------- prepare data --------------------
model_size = 960
obs_density = 4
nobs = int(model_size / obs_density)
model_grids = np.arange(1, model_size + 1)
obs_grids = model_grids[model_grids % obs_density == 0]
CMat = construct_GC_2d(120, model_size, obs_grids)
gc_weights = np.roll(CMat[0,:], -obs_density+1) + 2.0

plt.plot(range(960),gc_weights)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="339">

# %%
np.shape(np.tile(gc_weights,(6400,1,240)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8653b139cc32> in <module>
# ----> 1 np.shape(np.broadcast_to(gc_weights,(6400,960,240)))
#
# <__array_function__ internals> in broadcast_to(*args, **kwargs)
#
# ~/opt/miniconda3/envs/condapy3/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in broadcast_to(array, shape, subok)
#     180            [1, 2, 3]])
#     181     """
# --> 182     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     183
#     184
#
# ~/opt/miniconda3/envs/condapy3/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     123                          'negative')
#     124     extras = []
# --> 125     it = np.nditer(
#     126         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
# ...
