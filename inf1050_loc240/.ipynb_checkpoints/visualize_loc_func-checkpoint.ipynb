# %% [markdown]
# Lorenz 2005
# - F = 15.0 (constant)
# - observation : density=4, time frequency=50, err var=1.0
# - basic ensemble size: 40
# - independent ensemble size: 2000
# - basic_ens loc=240, inf=1.05
# - inde_ens loc=0(noloc), inf=1.05

# %% [markdown]
# ### 1.1 loc: kg_t/kg_f

# %%
# %matplotlib notebook
from construct_GC_2d import construct_GC_2d
import numpy as np
import matplotlib.pyplot as plt

model_size = 960
obs_density = 4
model_grids = np.arange(1, model_size + 1)
obs_grids = model_grids[model_grids % obs_density == 0]
CMat = construct_GC_2d(120, model_size, obs_grids)

beta = np.load('reg_loc_beta.npy')
eps = np.load('reg_loc_eps.npy')

plt.plot(range(model_size), beta+eps, label='regression')
plt.plot(range(model_size), CMat[0, :], label='GC')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="561">

# %%
plt.plot(range(model_size), eps, label='eps')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="515">

# %%
gc_locmat = np.load('gc_locmat.npy')
reg_locmat = np.load('reg_locmat.npy')

plt.plot(range(40),reg_locmat[9,:],label='regression')
plt.plot(range(40),gc_locmat[9,:],label='GC')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-69e5a56eaf4e> in <module>
# ----> 1 gc_locmat = np.load('gc_locmat.npy')
#       2 reg_locmat = np.load('reg_locmat.npy')
#       3
#       4 plt.plot(range(40),reg_locmat[9,:],label='regression')
#       5 plt.plot(range(40),gc_locmat[9,:],label='GC')
#
# ~/opt/miniconda3/envs/condapy3/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gc_locmat.npy'

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt


MSE_gc = np.load('mse_gc.npy')
MSE_reg = np.load('mse_reg_1.npy')

model_size = 960
xx = range(model_size)
plt.plot(xx, MSE_gc, label='mse_gc')
plt.plot(xx, MSE_reg, label='mse_reg')
# plt.plot(xx, MSE_ai, label='mse_ai')
plt.legend()
plt.show()

print('mean_mse_gc:',np.mean(MSE_gc))
print('mean_mse_reg:',np.mean(MSE_reg))
# Out:
# <img src="data:image/png;base64,..." width="581">
# mean_mse_gc: 8.393165425698624e-05
# mean_mse_reg: 2.9920749634209723e-05
