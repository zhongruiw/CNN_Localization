# %% [markdown]
# t-test using [scipy.stats.ttest_ind module](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html).
# 2-tailed test.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_reg.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='reg')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('reg prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs Reg. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs Reg. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# reg prior:  0.3185640169706165
# GC vs Reg. t=-16.35648, p=0.00000
# GC_op vs Reg. t=-18.10000, p=0.00000
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/2d/prior_rmse_reg_2d.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='reg_2d')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('reg 2d prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs Reg_2d. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs Reg_2d. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# reg 2d prior:  0.32224710200088064
# GC vs Reg_2d. t=-17.36089, p=0.00000
# GC_op vs Reg_2d. t=-19.07307, p=0.00000
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/ai/advance/Loss_Kg_t/SRCNN_DNN/distance_only/debug_481/mean/prior_rmse_srcnn_dnn.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='SRCNN_DNN_static')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('SRCNN_DNN_static prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs SRCNN_DNN_static. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs SRCNN_DNN_static. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# SRCNN_DNN_static prior:  0.32101368005749836
# GC vs SRCNN_DNN_static. t=-17.38663, p=0.00000
# GC_op vs SRCNN_DNN_static. t=-19.15707, p=0.00000
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/ai/advance/Loss_Kg_t/SRCNN_DNN/distance_only/debug_481/prior_rmse_ai.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='SRCNN_DNN')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('SRCNN_DNN prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs SRCNN_DNN. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs SRCNN_DNN. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# SRCNN_DNN prior:  0.31858564715968907
# GC vs SRCNN_DNN. t=-16.44729, p=0.00000
# GC_op vs SRCNN_DNN. t=-18.20247, p=0.00000
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/ai/advance/Loss_Kg_t/SRCNN_Dong/kg_no_shift/prior_rmse.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='SRCNN')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('SRCNN prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs SRCNN. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs SRCNN. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# SRCNN prior:  0.2700894212598487
# GC vs SRCNN. t=2.30458, p=0.02126
# GC_op vs SRCNN. t=0.68710, p=0.49207
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/kg_t/advance/prior_rmse.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='kg_t')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('kg_t prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs kg_t. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs kg_t. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# kg_t prior:  0.26960690913417606
# GC vs kg_t. t=2.47339, p=0.01344
# GC_op vs kg_t. t=0.88058, p=0.37862
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/elf/distance_only/elf_ztest/debug_481/prior_rmse_elf.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='ELF')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('ELF prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs ELF. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs ELF. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# ELF prior:  0.3211396158887432
# GC vs ELF. t=-16.72353, p=0.00000
# GC_op vs ELF. t=-18.40034, p=0.00000
# GC vs GC_op t=1.62646, p=0.10397

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/ai/advance/Loss_xt/SRCNN_Dong/tune/219_21_5/prior_rmse.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='SRCNN_xt')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('SRCNN_xt prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs SRCNN_xt. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs SRCNN_xt. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# SRCNN_xt prior:  0.2727738868055444
# GC vs SRCNN_xt. t=1.17335, p=0.24076
# GC_op vs SRCNN_xt. t=-0.45504, p=0.64912
# GC vs GC_op t=1.62646, p=0.10397

# %% [markdown]
# ## spatially averaged

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

rmse_gc = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/reg/advance/distance_only/debug_481/without_res/prior_rmse_gc240.npy')
rmse_gc_op = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/train/gc/330-480/prior_rmse.npy')
rmse_reg = np.load('/Users/ree/Documents/DataAssimilization/AI_localization/L05/server/inf1050_loc240/4040/ai/advance/Loss_xt/SRCNN_Dong/tune/219_21_5/prior_rmse.npy')

cut = 41
rmse_gc = rmse_gc[cut:]
rmse_gc_op = rmse_gc_op[cut:,-2]
rmse_reg = rmse_reg[cut:]

model_size = 960
nobstime = 1441-cut

xx = range(nobstime)
plt.plot(xx, rmse_gc, label='gc')
plt.plot(xx, rmse_gc_op, label='gc_optimal')
plt.plot(xx, rmse_reg, label='SRCNN_xt')
plt.legend()
# plt.ylim(0,0.0005)
plt.show()
print('GC prior: ',np.mean(rmse_gc))
print('GC optimal prior: ',np.mean(rmse_gc_op))
print('SRCNN_xt prior: ',np.mean(rmse_reg))

t, p = ttest_ind(rmse_gc, rmse_reg)
print('GC vs SRCNN_xt. t={0:.5f}, p={1:.5f}'.format(t,p))
t1, p1 = ttest_ind(rmse_gc_op, rmse_reg)
print('GC_op vs SRCNN_xt. t={0:.5f}, p={1:.5f}'.format(t1,p1))
t1, p1 = ttest_ind(rmse_gc, rmse_gc_op)
print('GC vs GC_op t={0:.5f}, p={1:.5f}'.format(t1,p1))
# Out:
# GC prior:  0.27559045254931563
# GC optimal prior:  0.2717006238903875
# SRCNN_xt prior:  0.2727738868055444
# GC vs SRCNN_xt. t=1.17335, p=0.24076
# GC_op vs SRCNN_xt. t=-0.45504, p=0.64912
# GC vs GC_op t=1.62646, p=0.10397
